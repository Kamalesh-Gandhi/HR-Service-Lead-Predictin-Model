# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
# Load Train and Test datasets
train_df = pd.read_csv('DataSets\Processed_train_data.csv')
test_df = pd.read_csv('DataSets\Processed_test_data.csv')

# Define target variable
target = 'is_hot_lead'

# Splitting features and target
X_train = train_df.drop(columns=[target])
y_train = train_df[target]

X_test = test_df.drop(columns=[target])
y_test = test_df[target]

# %%
# Apply SMOTE to balance the dataset
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

print(f" SMOTE Applied: Before ({y_train.value_counts().to_dict()}), After ({y_train_smote.value_counts().to_dict()})")
# Out:
#  SMOTE Applied: Before ({0: 16980, 1: 2985}), After ({0: 16980, 1: 16980})

# %%
# Apply Standardization (Feature Scaling)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_smote)  # Fit & transform training data
X_test_scaled = scaler.transform(X_test)  # Transform test data

# Save the scaler for future use
joblib.dump(scaler, 'PKl_files/scaler.pkl')
# Out:
# ['PKl_files/scaler.pkl']

# %%
X_test.head(10)
# Out:
#    company_name  industry  funding_rounds  total_funding  job_postings_30d  \
# 0            -1         2        3.265246     2425223.28          7.201083
# 1            -1         3        1.912502     3988620.41         14.562457
# 2            -1         4        5.425373     2645234.46         14.797940
# 3            -1         2        0.987882     3194492.15         14.946632
# 4            -1         2        3.583654      884497.73          9.714369
# 5            -1         3        2.340446     6076529.42         12.142480
# 6         14877         1        3.421293     2256189.13         12.677383
# 7         10897         0        2.047862     6243040.88         10.374001
# 8            -1         2        4.473383     4776184.28          7.923417
# 9            -1         4        1.002375    10849688.67          7.450955
#
#    employee_growth_pct  hiring_roles  industry_growth_rate  \
# 0             5.569041             2                   8.0
# 1            46.348625             0                   7.1
# 2            34.121940             1                  16.0
# 3             4.969312             3                  21.1
# 4            -7.111839             2                   8.1
# 5             0.278950             3                   6.7
# 6            23.829309             2                  15.1
# 7            29.645961             3                  11.9
# 8            -1.367018             3                   7.0
# 9            30.147126             1                  11.5
#
#    regional_employment_trend  funding_per_employee  days_since_last_funding  \
# 0                        8.4           3566.504824                     1280
# 1                        4.3            890.317056                     1729
# 2                       14.8            669.679610                     1449
# 3                        5.9           5414.393475                      849
# 4                       -4.3          -1499.148695                     1572
# 5                        0.9          46742.534000                      216
# 6                       -4.8            951.978536                      422
# 7                       12.3           2190.540660                     1570
# 8                       -4.7         -79603.071333                     1189
# 9                       -3.6           4033.341513                      345
#
#    growth_momentum  funding_year  funding_month  funding_day  funding_weekday  \
# 0      16976562.96          2021              8           20                4
# 1      55840685.74          2020              5           28                3
# 2      37033282.44          2021              3            4                3
# 3      41528397.95          2022             10           25                1
# 4       9729475.03          2020             11            1                6
# 5      72918353.04          2024              7           19                4
# 6      27074269.56          2023             12           26                1
# 7      68673449.68          2020             11            3                1
# 8      42985658.52          2021             11           19                4
# 9      75947820.69          2024              3           12                1
#
#    funding_quarter
# 0                3
# 1                2
# 2                1
# 3                4
# 4                4
# 5                3
# 6                4
# 7                4
# 8                4
# 9                1

# %%
X_train_smote.head(10)
# Out:
#    company_name  industry  funding_rounds  total_funding  job_postings_30d  \
# 0          9973         2        1.911533     3795597.04         10.995177
# 1          9938         1        3.221005     5792195.29          5.052385
# 2         14014         4        3.975966      191991.00          5.008945
# 3         12831         0        2.842382      890042.57          9.882709
# 4          3203         2        2.264359     3369725.77         11.461475
# 5         14637         1        4.875184     2881335.43          6.869437
# 6          9405         0        0.900992     7941005.00          7.892017
# 7          3444         0        1.170316     1716573.56         11.931091
# 8          6539         3        3.337948      178278.14          7.100843
# 9         10332         4        3.864427     2266813.43          9.548882
#
#    employee_growth_pct  hiring_roles  industry_growth_rate  \
# 0            -8.355216             2                  11.5
# 1            20.602718             1                  23.9
# 2             0.456013             2                  20.5
# 3             1.202142             2                  23.2
# 4            22.633126             1                   9.0
# 5            32.667976             1                  21.0
# 6            22.698968             1                  14.5
# 7             8.556498             0                  29.4
# 8            30.058273             0                  25.2
# 9            -2.022682             0                  14.4
#
#    regional_employment_trend  funding_per_employee  days_since_last_funding  \
# 0                       -0.2          -5930.620375                     1317
# 1                       10.5           2106.252833                     1734
# 2                       -1.5           1371.364286                     1750
# 3                       13.9           4238.297952                      681
# 4                        8.6           1567.314312                      330
# 5                        1.0            752.306901                     1252
# 6                       -3.6           3214.981781                     1085
# 7                       -1.2           1928.734337                     1437
# 8                       10.4             52.745012                      173
# 9                        9.2         -25186.815889                       75
#
#    growth_momentum  funding_year  funding_month  funding_day  funding_weekday  \
# 0      45547164.48          2021              7           14                2
# 1      34753171.74          2020              5           23                5
# 2        959955.00          2020              5            7                3
# 3       8010383.13          2023              4           11                1
# 4      40436709.24          2024              3           27                2
# 5      20169348.01          2021              9           17                4
# 6      63528040.00          2022              3            3                3
# 7      24032029.84          2021              3           16                1
# 8       1426225.12          2024              8           31                5
# 9      27201761.16          2024             12            7                5
#
#    funding_quarter
# 0                3
# 1                2
# 2                2
# 3                2
# 4                1
# 5                3
# 6                1
# 7                1
# 8                3
# 9                4

# %% [markdown]
# # Model Training and Evaluation

# %%
# Define models in a dictionary (Including Gradient Boosting)
models = {
    "Logistic Regression": LogisticRegression(class_weight='balanced', random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=200, class_weight='balanced', random_state=42),
    "XGBoost": XGBClassifier(n_estimators=200, learning_rate=0.05, use_label_encoder=False, eval_metric='logloss'),
    "Decision Tree": DecisionTreeClassifier(class_weight='balanced', random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=200, learning_rate=0.05, random_state=42)
}

# Dictionary to store results
results = []

# Loop through models, train and evaluate
for name, model in models.items():
    print(f"\n🔹 Training {name}...")
    
    # Train the model with SMOTE data
    model.fit(X_train_scaled, y_train_smote)
    
    # Make predictions
    y_pred = model.predict(X_test_scaled)
    
    # Calculate metrics
    acc = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    
    # Append results to the list
    results.append({
        "Model": name,
        "Accuracy": acc,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "Confusion Matrix": conf_matrix
    })

    # Save the trained model
    joblib.dump(model, f"PKl_files/{name.replace(' ', '_')}.pkl")

# Convert results to a DataFrame
results_df = pd.DataFrame(results)
# Out:
# 🔹 Training Logistic Regression...
#
# 🔹 Training Random Forest...
#
# 🔹 Training XGBoost...
# d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py:158: UserWarning: [23:26:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 🔹 Training Decision Tree...
#
# 🔹 Training Gradient Boosting...

# %%
results_df
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score  \
# 0  Logistic Regression  0.879607   0.599179  0.587131  0.593094
# 1        Random Forest  0.950521   0.798802  0.894102  0.843770
# 2              XGBoost  0.959135   0.820331  0.930295  0.871859
# 3        Decision Tree  0.925280   0.746367  0.757373  0.751830
# 4    Gradient Boosting  0.946314   0.766147  0.922252  0.836983
#
#             Confusion Matrix
# 0  [[3953, 293], [308, 438]]
# 1   [[4078, 168], [79, 667]]
# 2   [[4094, 152], [52, 694]]
# 3  [[4054, 192], [181, 565]]
# 4   [[4036, 210], [58, 688]]

# %% [markdown]
# # HyperParameter Tuning

# %% [markdown]
# Training Model using randomized search

# %%
# Define parameter distributions for Randomized Search
param_distributions = {
    'n_estimators': np.arange(100, 500, 50),
    'learning_rate': np.linspace(0.01, 0.2, 10),
    'max_depth': np.arange(3, 10, 2),
    'subsample': np.linspace(0.6, 1.0, 5),
    'colsample_bytree': np.linspace(0.6, 1.0, 5),
    'gamma': np.linspace(0, 1, 5),
    'reg_lambda': np.linspace(0, 2, 5),
    'reg_alpha': np.linspace(0, 2, 5),
}

# Initialize XGBoost model
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

# Perform Randomized Search with 5-fold cross-validation
random_search = RandomizedSearchCV(
    xgb_model, 
    param_distributions, 
    n_iter=50,  # Number of random combinations to try
    scoring='f1',  # Optimizing for F1-score
    cv=5, 
    verbose=2, 
    n_jobs=-1, 
    random_state=42
)

# Fit the model
random_search.fit(X_train_scaled, y_train_smote)

# Get the best parameters
best_params = random_search.best_params_
print(f"✅ Best Hyperparameters for XGBoost: {best_params}")

# Train the best XGBoost model with tuned parameters
best_xgb = xgb.XGBClassifier(**best_params, use_label_encoder=False, eval_metric='logloss', random_state=42)
best_xgb.fit(X_train_scaled, y_train_smote)

# Save the best model
joblib.dump(best_xgb, "PKl_files/best_xgboost_model.pkl")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 1 fits failed out of a total of 250.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\sklearn.py", line 1580, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\sklearn.py", line 603, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\sklearn.py", line 1065, in _create_dmatrix
#     return QuantileDMatrix(
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 1573, in __init__
#     self._init(
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 1632, in _init
#     it.reraise()
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 569, in reraise
#     raise exc  # pylint: disable=raising-bad-type
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 550, in _handle_exception
#     return fn()
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 637, in <lambda>
#     return self._handle_exception(lambda: self.next(input_data), 0)
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\data.py", line 1402, in next
#     input_data(**self.kwargs)
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 626, in input_data
#     self.proxy.set_info(
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 954, in set_info
#     self.set_label(label)
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 1092, in set_label
#     dispatch_meta_backend(self, label, "label", "float")
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\data.py", line 1348, in dispatch_meta_backend
#     _meta_from_pandas_series(data, name, dtype, handle)
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\data.py", line 679, in _meta_from_pandas_series
#     _meta_from_numpy(data, name, dtype, handle)
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\data.py", line 1279, in _meta_from_numpy
#     _check_call(_LIB.XGDMatrixSetInfoFromInterface(handle, c_str(field), interface_str))
#   File "d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [23:31:36] C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\data\array_interface.cu:44: Check failed: err == cudaGetLastError() (0 vs. 46) :
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.95845926        nan 0.96410057 0.95943871 0.96557503 0.95395439
#  0.96561223 0.95610634 0.9668     0.96066231 0.96506194 0.95703341
#  0.96407437 0.96434169 0.96596526 0.96045822 0.96303564 0.96278358
#  0.96593006 0.95627793 0.95918859 0.95918529 0.96438507 0.95800005
#  0.96371778 0.96307726 0.96043234 0.96064573 0.96465301 0.96385242
#  0.96810517 0.96500586 0.95879587 0.9631072  0.9666648  0.96389301
#  0.96446623 0.96140642 0.96210164 0.95733805 0.96027529 0.96518134
#  0.95943994 0.96492693 0.96587948 0.96329666 0.95487703 0.95734135
#  0.96292779 0.96072354]
#   warnings.warn(
# d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py:158: UserWarning: [23:34:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ✅ Best Hyperparameters for XGBoost: {'subsample': 0.7, 'reg_lambda': 2.0, 'reg_alpha': 0.5, 'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.1788888888888889, 'gamma': 0.0, 'colsample_bytree': 0.7}
# d:\DataScience\GUVI\DataScience_GUVI_Projects\Customer_Conversion_Analysis_MLOps\customer_Convesion_Analysis_VENV\lib\site-packages\xgboost\core.py:158: UserWarning: [23:34:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ['PKl_files/best_xgboost_model.pkl']

# %% [markdown]
# Testing Using trained model by Randomized Search

# %%
Hypertuned_results=[]

# Load the best XGBoost model
best_xgb = joblib.load("PKl_files/best_xgboost_model.pkl")

# Make predictions on the test set
y_test_pred = best_xgb.predict(X_test_scaled)

# Compute evaluation metrics
xgb_best_acc = accuracy_score(y_test, y_test_pred)
xgb_best_precision = precision_score(y_test, y_test_pred)
xgb_best_recall = recall_score(y_test, y_test_pred)
xgb_best_f1 = f1_score(y_test, y_test_pred)
xgb_best_conf_matrix = confusion_matrix(y_test, y_test_pred)

# Append the best tuned model's performance to the results DataFrame
best_model_results = {
    "Model": "XGBoost (Tuned)",
    "Accuracy": xgb_best_acc,
    "Precision": xgb_best_precision,
    "Recall": xgb_best_recall,
    "F1 Score": xgb_best_f1,
    "Confusion Matrix": xgb_best_conf_matrix
}

# Append the  result to the DataFrame
Hypertuned_results.append(best_model_results)
Hypetuned_df = pd.DataFrame(Hypertuned_results)

# %%
Hypetuned_df
# Out:
#              Model  Accuracy  Precision  Recall  F1 Score  \
# 0  XGBoost (Tuned)  0.969351   0.863804  0.9437  0.901986
#
#            Confusion Matrix
# 0  [[4135, 111], [42, 704]]

# %% [markdown]
# # Predicting 'is_hot_lead' for Holdout Data

# %%
df_holdout = pd.read_csv(r'DataSets\Processed_holdout_data.csv')

# %%
df_holdout.head(10)
# Out:
#     company_id  company_name  industry  funding_rounds  total_funding  \
# 0  COMP_000000            -1         3               7     4189415.46
# 1  COMP_000001         14332         3               1     3964281.97
# 2  COMP_000002            -1         0               2     7548375.72
# 3  COMP_000003          3412         0               3     8418569.83
# 4  COMP_000004          5732         1               2     2449746.19
# 5  COMP_000005            -1         4               4     3463349.02
# 6  COMP_000006            -1         4               2     2820737.83
# 7  COMP_000007            -1         2               3     1988942.70
# 8  COMP_000008         11329         4               4     6413583.09
# 9  COMP_000009            -1         1               2     8342077.23
#
#    job_postings_30d  employee_growth_pct  hiring_roles  industry_growth_rate  \
# 0                 9                 -2.0             3                  17.3
# 1                 5                 20.1             1                   8.8
# 2                 9                  7.0             2                  15.9
# 3                 4                 39.7             3                  17.5
# 4                13                 34.2             0                  27.0
# 5                 8                 27.4             0                  24.1
# 6                15                 38.1             1                  26.2
# 7                13                 46.9             0                  22.1
# 8                10                  1.5             2                  25.3
# 9                 8                 33.6             1                  29.5
#
#    regional_employment_trend  funding_per_employee  days_since_last_funding  \
# 0                       12.9         -41894.154600                     1793
# 1                       -2.8           1878.806621                      523
# 2                       -2.8           9435.469650                      259
# 3                        2.3           2068.444676                     1155
# 4                        4.4            695.950622                     1769
# 5                        5.5           1219.489092                      678
# 6                        8.1            721.416325                      586
# 7                        6.4            415.228121                      528
# 8                       -3.4          25654.332360                      867
# 9                       -0.3           2411.004980                      941
#
#    growth_momentum  funding_year  funding_month  funding_day  funding_weekday  \
# 0      37704739.14          2020              3           25                2
# 1      19821409.85          2023              9           16                5
# 2      67935381.48          2024              6            6                3
# 3      33674279.32          2021             12           23                3
# 4      31846700.47          2020              4           18                5
# 5      27706792.16          2023              4           14                4
# 6      42311067.45          2023              7           15                5
# 7      25856255.10          2023              9           11                0
# 8      64135830.90          2022             10            7                4
# 9      66736617.84          2022              7           25                0
#
#    funding_quarter
# 0                1
# 1                3
# 2                2
# 3                4
# 4                2
# 5                2
# 6                3
# 7                3
# 8                4
# 9                3

# %%
df_holdout.describe()
# Out:
#        company_name    industry  funding_rounds  total_funding  \
# count    498.000000  498.000000      498.000000   4.980000e+02
# mean    1960.791165    2.058233        3.110442   4.118849e+06
# std     4176.186818    1.425064        1.409172   2.927568e+06
# min       -1.000000    0.000000        1.000000   1.073545e+05
# 25%       -1.000000    1.000000        2.000000   1.740622e+06
# 50%       -1.000000    2.000000        3.000000   3.595327e+06
# 75%       -1.000000    3.000000        4.000000   5.979098e+06
# max    16211.000000    4.000000        8.000000   1.521680e+07
#
#        job_postings_30d  employee_growth_pct  hiring_roles  \
# count        498.000000           498.000000    498.000000
# mean           9.726908            20.677510      1.578313
# std            3.152993            17.291727      1.167506
# min            1.000000            -9.600000      0.000000
# 25%            8.000000             5.800000      0.000000
# 50%           10.000000            21.450000      2.000000
# 75%           12.000000            35.875000      3.000000
# max           20.000000            50.000000      3.000000
#
#        industry_growth_rate  regional_employment_trend  funding_per_employee  \
# count            498.000000                 498.000000            498.000000
# mean              17.439157                   4.848594            971.644017
# std                7.213606                   5.784153          42600.759002
# min                5.000000                  -5.000000        -416600.634000
# 25%               11.425000                  -0.500000            357.761146
# 50%               17.700000                   4.900000           1140.484994
# 75%               23.875000                   9.600000           2718.000973
# max               29.900000                  15.000000         564662.337500
#
#        days_since_last_funding  growth_momentum  funding_year  funding_month  \
# count               498.000000     4.980000e+02    498.000000     498.000000
# mean                908.676707     4.121133e+07   2022.142570       6.620482
# std                 511.020990     3.474048e+07      1.396228       3.499719
# min                   2.000000     3.777140e+05   2020.000000       1.000000
# 25%                 485.250000     1.456593e+07   2021.000000       4.000000
# 50%                 872.500000     3.138121e+07   2022.000000       6.000000
# 75%                1348.000000     6.116454e+07   2023.000000      10.000000
# max                1823.000000     1.978184e+08   2025.000000      12.000000
#
#        funding_day  funding_weekday  funding_quarter
# count   498.000000       498.000000       498.000000
# mean     15.985944         2.861446         2.518072
# std       8.666281         1.997705         1.138619
# min       1.000000         0.000000         1.000000
# 25%       9.000000         1.000000         2.000000
# 50%      16.000000         3.000000         2.000000
# 75%      23.000000         5.000000         4.000000
# max      31.000000         6.000000         4.000000

# %%
df_holdout.isna().sum()
# Out:
# company_id                   0
# company_name                 0
# industry                     0
# funding_rounds               0
# total_funding                0
# job_postings_30d             0
# employee_growth_pct          0
# hiring_roles                 0
# industry_growth_rate         0
# regional_employment_trend    0
# funding_per_employee         0
# days_since_last_funding      0
# growth_momentum              0
# funding_year                 0
# funding_month                0
# funding_day                  0
# funding_weekday              0
# funding_quarter              0
# dtype: int64

# %%
df_holdout.duplicated().sum()
# Out:
# 0

# %%
#dropping the company_id column before predicting is hot lead
X_data = df_holdout.drop(columns=['company_id'])

# %%
X_data.head(10)
# Out:
#    company_name  industry  funding_rounds  total_funding  job_postings_30d  \
# 0            -1         3               7     4189415.46                 9
# 1         14332         3               1     3964281.97                 5
# 2            -1         0               2     7548375.72                 9
# 3          3412         0               3     8418569.83                 4
# 4          5732         1               2     2449746.19                13
# 5            -1         4               4     3463349.02                 8
# 6            -1         4               2     2820737.83                15
# 7            -1         2               3     1988942.70                13
# 8         11329         4               4     6413583.09                10
# 9            -1         1               2     8342077.23                 8
#
#    employee_growth_pct  hiring_roles  industry_growth_rate  \
# 0                 -2.0             3                  17.3
# 1                 20.1             1                   8.8
# 2                  7.0             2                  15.9
# 3                 39.7             3                  17.5
# 4                 34.2             0                  27.0
# 5                 27.4             0                  24.1
# 6                 38.1             1                  26.2
# 7                 46.9             0                  22.1
# 8                  1.5             2                  25.3
# 9                 33.6             1                  29.5
#
#    regional_employment_trend  funding_per_employee  days_since_last_funding  \
# 0                       12.9         -41894.154600                     1793
# 1                       -2.8           1878.806621                      523
# 2                       -2.8           9435.469650                      259
# 3                        2.3           2068.444676                     1155
# 4                        4.4            695.950622                     1769
# 5                        5.5           1219.489092                      678
# 6                        8.1            721.416325                      586
# 7                        6.4            415.228121                      528
# 8                       -3.4          25654.332360                      867
# 9                       -0.3           2411.004980                      941
#
#    growth_momentum  funding_year  funding_month  funding_day  funding_weekday  \
# 0      37704739.14          2020              3           25                2
# 1      19821409.85          2023              9           16                5
# 2      67935381.48          2024              6            6                3
# 3      33674279.32          2021             12           23                3
# 4      31846700.47          2020              4           18                5
# 5      27706792.16          2023              4           14                4
# 6      42311067.45          2023              7           15                5
# 7      25856255.10          2023              9           11                0
# 8      64135830.90          2022             10            7                4
# 9      66736617.84          2022              7           25                0
#
#    funding_quarter
# 0                1
# 1                3
# 2                2
# 3                4
# 4                2
# 5                2
# 6                3
# 7                3
# 8                4
# 9                3

# %%
X_data.describe()
# Out:
#        company_name    industry  funding_rounds  total_funding  \
# count    498.000000  498.000000      498.000000   4.980000e+02
# mean    1960.791165    2.058233        3.110442   4.118849e+06
# std     4176.186818    1.425064        1.409172   2.927568e+06
# min       -1.000000    0.000000        1.000000   1.073545e+05
# 25%       -1.000000    1.000000        2.000000   1.740622e+06
# 50%       -1.000000    2.000000        3.000000   3.595327e+06
# 75%       -1.000000    3.000000        4.000000   5.979098e+06
# max    16211.000000    4.000000        8.000000   1.521680e+07
#
#        job_postings_30d  employee_growth_pct  hiring_roles  \
# count        498.000000           498.000000    498.000000
# mean           9.726908            20.677510      1.578313
# std            3.152993            17.291727      1.167506
# min            1.000000            -9.600000      0.000000
# 25%            8.000000             5.800000      0.000000
# 50%           10.000000            21.450000      2.000000
# 75%           12.000000            35.875000      3.000000
# max           20.000000            50.000000      3.000000
#
#        industry_growth_rate  regional_employment_trend  funding_per_employee  \
# count            498.000000                 498.000000            498.000000
# mean              17.439157                   4.848594            971.644017
# std                7.213606                   5.784153          42600.759002
# min                5.000000                  -5.000000        -416600.634000
# 25%               11.425000                  -0.500000            357.761146
# 50%               17.700000                   4.900000           1140.484994
# 75%               23.875000                   9.600000           2718.000973
# max               29.900000                  15.000000         564662.337500
#
#        days_since_last_funding  growth_momentum  funding_year  funding_month  \
# count               498.000000     4.980000e+02    498.000000     498.000000
# mean                908.676707     4.121133e+07   2022.142570       6.620482
# std                 511.020990     3.474048e+07      1.396228       3.499719
# min                   2.000000     3.777140e+05   2020.000000       1.000000
# 25%                 485.250000     1.456593e+07   2021.000000       4.000000
# 50%                 872.500000     3.138121e+07   2022.000000       6.000000
# 75%                1348.000000     6.116454e+07   2023.000000      10.000000
# max                1823.000000     1.978184e+08   2025.000000      12.000000
#
#        funding_day  funding_weekday  funding_quarter
# count   498.000000       498.000000       498.000000
# mean     15.985944         2.861446         2.518072
# std       8.666281         1.997705         1.138619
# min       1.000000         0.000000         1.000000
# 25%       9.000000         1.000000         2.000000
# 50%      16.000000         3.000000         2.000000
# 75%      23.000000         5.000000         4.000000
# max      31.000000         6.000000         4.000000

# %%
# standardization the df_holdout data
X_data_scaled = scaler.transform(X_data)

# %% [markdown]
# predicting 'is_hot_lead' for processed_holdout_data

# %%
# Make predictions
predictions = best_xgb.predict(X_data_scaled)

# Create output DataFrame
output = pd.DataFrame({"company_id": df_holdout['company_id'], "Is Hot Lead": predictions})

# Save predictions
output.to_csv("Datasets/submission.csv", index=False)
